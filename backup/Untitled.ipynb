# %%
import pandas as pd
df = pd.read_csv("./6 class csv.csv")
df.head()
# Out:
#    Luminosity(L/Lo)  Radius(R/Ro)  Unnamed: 2  Star type Star color  \
# 0          0.002400        0.1700         NaN          0        Red
# 1          0.000500        0.1542         NaN          0        Red
# 2          0.000300        0.1020         NaN          0        Red
# 3          0.000200        0.1600         NaN          0        Red
# 4          0.000138        0.1030         NaN          0        Red
#
#   Spectral Class  Temperature (K)  Absolute magnitude
# 0              M             3068               16.12
# 1              M             3042               16.60
# 2              M             2600               18.70
# 3              M             2800               16.65
# 4              M             1939               20.06

# %%
import matplotlib.pyplot as plt

# Scatter plot with colored points
plt.scatter(df['Temperature (K)'],df['Absolute magnitude'], s=22)

# Reverse the y-axis for a standard H-R diagram
plt.gca().invert_yaxis()
plt.gca().invert_xaxis()

plt.xlabel('log.Teff [K]')
plt.ylabel('Absolute magnitude')
plt.title('Hertzsprung-Russell Diagram')

plt.grid(True)
plt.show()
